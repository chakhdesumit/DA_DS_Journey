# %% [markdown]
# # Strings

# %%
print("Hello")
print("Hello")
# Out:
# Hello
# Hello

# %%
print("Working now")
# Out:
# Working now

# %% [markdown]
# Quotes inside the quotes

# %%
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
# Out:
# It's alright
# He is called 'Johnny'
# He is called "Johnny"

# %% [markdown]
# Assign String to a Vriable

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %% [markdown]
# Strings are Arrays

# %%
a = "Hello World"
print(a[1])
# Out:
# e

# %% [markdown]
# Looping through a string

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# String length

# %%
a = "Hello, World!"
print(len(a))
# Out:
# 13

# %% [markdown]
# Check String

# %%
txt = "The best thing in life are free!"
print("free" in txt)
# Out:
# True

# %%
txt = "The best thing in life are free!"
if "free" in txt:
    print("Yes, 'free' is present.")
# Out:
# Yes, 'free' is present.

# %% [markdown]
# Check if not

# %%
txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")
# Out:
# No, 'expensive' is NOT present.

# %% [markdown]
# ### Slicing Strings
# You can return a range of characters by using the slice syntax.
# Specify the start index and the end index, separated by a colon, to return a part of the string.

# %%
## Get the characters from position 2 to position 5 (not included):
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %% [markdown]
# Slice from the start

# %%
## by leaving out the start index, the range will start at the firs characters:
b = "Hello, World!"
print(b[:5])
# Out:
# Hello

# %% [markdown]
# Slice to the End

# %%
## By leaving out the end index, the range will go to the end:
b = "Hello, World!"
print(b[2:])
# Out:
# llo, World!

# %% [markdown]
# ### Negative Indexing

# %%
## Use negative indexes to start the slice from the end of the string:
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %% [markdown]
# ### Modifying Strings

# %% [markdown]
# Upper Case

# %%
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %% [markdown]
# Lower Case

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %% [markdown]
# Remove Whitespace :- Whitespace is the space before and/or after the actual text, and very often you want to remove this space.

# %%
## The strip() method removes any whitespace from the beginning or the end.
a = "Hello, World!"
print(a.strip())
# Out:
# Hello, World!

# %% [markdown]
# Replace String

# %%
## The replace() method replaces a string with another string:
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %% [markdown]
# Split String :- The split() method returns a list where the text between the specified separator becomes the list items.

# %%
## The split() method splits the string into substrings if it finds instances of the separator:
a = "Hello, World!"
print(a.split(","))
# Out:
# ['Hello', ' World!']

# %% [markdown]
# String Format

# %%
age = 36
## This will produce an error:
txt = "My name is Sumit, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 age = 36
#       2 ## This will produce an error:
# ----> 3 txt = "My name is Sumit, I am " + age
#       4 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
txt = "For only {price:.2f} dollars!"
print(txt.format(price = 49)) ## Displays the price with 2 decimals {price:.2f}
# Out:
# For only 49.00 dollars!

# %% [markdown]
# The Placeholders

# %%
txt1 = "My name is {frame}, I am {age}".format(frame = "Sumit", age = 24)

# %% [markdown]
# F String

# %%
age = 24
txt = f"My name is Sumit, i am {age}"
print(txt)
# Out:
# My name is Sumit, i am 24

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %% [markdown]
# Escape Characters

# %% [markdown]
# To insert characters that are illegal in a string, use an escape character.
#
# An escape character is a backslash \ followed by the character you want to insert.
#
# An example of an illegal character is a double quote inside a string that is surrounded by double quotes:

# %%
txt = "We are the so-called "vikings" from the north"
# Out:
#   Cell In[8], line 1
#     txt = "We are the so-called "vikings" from the north"
#                                  ^
# SyntaxError: invalid syntax

# %%
## to fix the problem, use the escape character \":
txt = "We are the so-called \"vikings\" from the north"
print(txt)
# Out:
# We are the so-called "vikings" from the north

# %% [markdown]
# String Methods

# %% [markdown]
# Cleaning Strings : strip(), lstrip(), rstrip()

# %%
## Strip() : Remove spaces from both sides
text = "     Hello     "
print(text.strip())
# Out:
# Hello

# %%
## lstrip()/rstrip() : Removes left right spaces
text = "       Hello   "
print(text.lstrip())
print(text.rstrip())
# Out:
# Hello
#        Hello

# %% [markdown]
# Replace/Modify

# %%
## replace : Replace text
text = "I like Java"
print(text.replace("Java", "Python"))
# Out:
# I like Python

# %% [markdown]
# Split & Join

# %%
## split() :- coverting string to list
data = "apple, mango, banana"
print(data.split(","))
# Out:
# ['apple', ' mango', ' banana']

# %%
## Jjoin() :  Convert list to string
words = ["Hello", "World"]
print(" ".join(words))
# Out:
# Hello World

# %% [markdown]
# Searching

# %%
## find() :  retunes position (or -1)
text = "data analyst"
print(text.find("analyst"))
# Out:
# 5

# %%
## count() : count occurrences
text = "banana"
print(text.count("a"))
# Out:
# 3

# %%
## startswith()/endswith() :
text = "data analyst"

print(text.startswith("data"))   # True
print(text.endswith("analyst"))  # True
# Out:
# True
# True

# %%
## in :
text = "data analyst"
print("data" in text)
# Out:
# True
